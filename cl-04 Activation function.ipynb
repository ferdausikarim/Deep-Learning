# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
random_data = np.arange(-5, 10, 0.1)

# %%
def visualization(function, yaxis = (-2.0, 2.0)):
    ylim = (yaxis)
    plt.locator_params(nbins = 5)
    plt.xticks(fontsize = 14)
    plt.yticks(fontsize = 14)
    plt.axhline(lw = 1, c = 'black')
    plt.axvline(lw = 1, c = 'black')
    plt.grid(alpha = 0.4, ls = '-.')
    plt.box(on = None)
    plt.plot(random_data, function(random_data),c='r', lw = 3)
    plt.show()

# %%
def sigmoid(data):
    return 1/(1 + np.exp(-data))

# %%
visualization(sigmoid, yaxis = (-0.5, 0.5))

# %%
Relu_activation_function = np.vectorize(lambda random_data: random_data if random_data>0  else 0)

# %%
visualization(Relu_activation_function, yaxis = (-3.0, 3.0))

# %%
for i in random_data:
    if i > 0:
        print(i)
# Out:
# 0.09999999999998188
# 0.19999999999998153
# 0.29999999999998117
# 0.3999999999999808
# 0.49999999999998046
# 0.5999999999999801
# 0.6999999999999797
# 0.7999999999999794
# 0.899999999999979
# 0.9999999999999787
# 1.0999999999999783
# 1.199999999999978
# 1.2999999999999776
# 1.3999999999999773
# 1.499999999999977
# 1.5999999999999766
# 1.6999999999999762
# 1.7999999999999758
# 1.8999999999999755
# 1.9999999999999751
# 2.0999999999999748
# 2.1999999999999744
# 2.299999999999974
# 2.3999999999999737
# 2.4999999999999734
# 2.599999999999973
# 2.6999999999999726
# 2.7999999999999723
# 2.899999999999972
# 2.9999999999999716
# 3.0999999999999712
# 3.199999999999971
# 3.2999999999999705
# 3.39999999999997
# 3.49999999999997
# 3.5999999999999694
# 3.699999999999969
# 3.7999999999999687
# 3.8999999999999684
# 3.999999999999968
# 4.099999999999968
# 4.199999999999967
# 4.299999999999967
# 4.399999999999967
# 4.499999999999966
# 4.599999999999966
# 4.6999999999999655
# 4.799999999999965
# 4.899999999999965
# 4.9999999999999645
# 5.099999999999964
# 5.199999999999964
# 5.299999999999963
# 5.399999999999963
# 5.499999999999963
# 5.599999999999962
# 5.699999999999962
# 5.799999999999962
# 5.899999999999961
# 5.999999999999961
# 6.099999999999961
# 6.19999999999996
# 6.29999999999996
# 6.3999999999999595
# 6.499999999999959
# 6.599999999999959
# 6.699999999999958
# 6.799999999999958
# 6.899999999999958
# 6.999999999999957
# 7.099999999999957
# 7.199999999999957
# 7.299999999999956
# 7.399999999999956
# 7.499999999999956
# 7.599999999999955
# 7.699999999999955
# 7.7999999999999545
# 7.899999999999954
# 7.999999999999954
# 8.099999999999953
# 8.199999999999953
# 8.299999999999953
# 8.399999999999952
# 8.499999999999952
# 8.599999999999952
# 8.699999999999951
# 8.799999999999951
# 8.89999999999995
# 8.99999999999995
# 9.09999999999995
# 9.19999999999995
# 9.29999999999995
# 9.399999999999949
# 9.499999999999948
# 9.599999999999948
# 9.699999999999948
# 9.799999999999947
# 9.899999999999947

# %%
data=np.array([-5, 10, 0.1])

# %%
def softmax(data):
    return np.exp(data)/np.sum(np.exp(data))

# %%
visualization(softmax, yaxis = (-0.3, 0.3))

# %%
eZi=np.exp(data)

# %%
eZj=np.sum(np.exp(data))

# %%
softmax=eZi/eZj

# %%
softmax
# Out:
# array([3.05886879e-07, 9.99949522e-01, 5.01721493e-05])

# %%
np.argmax(softmax)
# Out:
# 1
